# %% [markdown]
# ## Comparison FLR - SIM

# %%
source_index = 1

# %% [markdown]
# #### Imports
# Load the necessary modules

# %%
# imports
import os
os.environ["GPUBACKENDTOOLS_FORCE_BACKEND"] = "cuda12x"

from fastlisaresponse import ResponseWrapper, pyResponseTDI

from few.waveform import GenerateEMRIWaveform
from few.trajectory.inspiral import EMRIInspiral

from lisatools.detector import Orbits
from lisaconstants import ASTRONOMICAL_YEAR

import matplotlib.pyplot as plt
import numpy as np
import cupy as cp
import pandas as pd
import os
import h5py
from scipy.signal.windows import tukey
from h5py import File
from lisaconstants import ASTRONOMICAL_YEAR
from lisaorbits import OEMOrbits

from scipy.interpolate import CubicSpline

from lisatools.detector import EqualArmlengthOrbits, Orbits
from lisatools.utils.utility import AET

from fastlisaresponse.utils.parallelbase import FastLISAResponseParallelModule
YRSID_SI = ASTRONOMICAL_YEAR
from fastlisaresponse import pyResponseTDI

from multiprocessing.sharedctypes import Value
import numpy as np
from typing import Optional, List
import warnings
from typing import Tuple
from copy import deepcopy

import time
import h5py

# %%
import few
import lisatools
import fastlisaresponse
import gpubackendtools
print(f'''
few:              {few.__version__}
lisatools:        {lisatools.__version__}
fastlisaresponse: {fastlisaresponse.__version__}
gpubackendtools:  {gpubackendtools.__version__}
''')
# Out:
# few:              2.0.0
# lisatools:        1.2.8
# fastlisaresponse: 1.2.1a0.post1.dev48+g66fa859db
# gpubackendtools:  0.1.1

# %%
import few
for backend in ["cpu", "cuda11x", "cuda12x", "cuda", "gpu"]:
    print(f" - Backend '{backend}': {"available" if few.has_backend(backend) else "unavailable"}")
# Out:
#  - Backend 'cpu': available
#  - Backend 'cuda11x': unavailable
#  - Backend 'cuda12x': available
#  - Backend 'cuda': available
#  - Backend 'gpu': available

# %%
! pip install dotenv
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, dotenv
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [dotenv]
# Successfully installed dotenv-0.9.9 python-dotenv-1.2.2

# %%
from dotenv import load_dotenv

# Load variables from the .env file
load_dotenv()
my_password = os.getenv("LISA_CONSORTIUM_KEY")
my_username = os.getenv("LISA_CONSORTIUM_NAME")

# %%
# install mojito module
esa_gitlab_token = os.getenv("ESA_GITLAB_TOKEN")

# %%
import scipy 
scipy.__version__
# Out:
# '1.16.1'

# %%
# %pip install mojito --index-url https://__token__:{esa_gitlab_token}@gitlab.esa.int/api/v4/groups/29349/-/packages/pypi/simple
# Out:
# WARNING: Ignoring invalid distribution ~cipy (/home/lisauser/miniforge3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~cipy (/home/lisauser/miniforge3/lib/python3.12/site-packages)
# Looking in indexes: https://__token__:****@gitlab.esa.int/api/v4/groups/29349/-/packages/pypi/simple
# Collecting mojito
#   Using cached https://gitlab.esa.int/api/v4/groups/29349/-/packages/pypi/files/838add52d80496d5731f2642855d40b6a0b2a49f890bcb91a0eab312b0c11d54/mojito-0.4.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: attrs>=25.4.0 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (25.4.0)
# Requirement already satisfied: h5py>=3.15.1 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (3.15.1)
# Requirement already satisfied: lisaconstants>=2.0.1 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (2.0.1)
# Requirement already satisfied: numpy>=2.3.5 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (2.3.5)
# Requirement already satisfied: pooch>=1.8.2 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (1.8.2)
# Requirement already satisfied: scipy>=1.16.3 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (1.16.3)
# Requirement already satisfied: setuptools>=80.9.0 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (82.0.1)
# Requirement already satisfied: tqdm>=4.67.1 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from mojito) (4.67.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from lisaconstants>=2.0.1->mojito) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.4->lisaconstants>=2.0.1->mojito) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from pooch>=1.8.2->mojito) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from pooch>=1.8.2->mojito) (25.0)
# Requirement already satisfied: requests>=2.19.0 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from pooch>=1.8.2->mojito) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.8.2->mojito) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.8.2->mojito) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.8.2->mojito) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lisauser/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.8.2->mojito) (2025.11.12)
# WARNING: Ignoring invalid distribution ~cipy (/home/lisauser/miniforge3/lib/python3.12/site-packages)
# Installing collected packages: mojito
# WARNING: Ignoring invalid distribution ~cipy (/home/lisauser/miniforge3/lib/python3.12/site-packages)
# Successfully installed mojito-0.4.0
# WARNING: Ignoring invalid distribution ~cipy (/home/lisauser/miniforge3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~cipy (/home/lisauser/miniforge3/lib/python3.12/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The environment needed to reproduce the results in this notebook relies on a from source installation of the following three packages:
# - fastlisaresponse: clone lisa-on-gpu, checkout branch `tdi_on_fly`
# - LISAanalysistools: checkout branch `lisa_on_fly`
# - gpu_backend_tools: checkout branch `spline`

# %% [markdown]
# #### Load correct dataset
# We load the correct downsampled dataset containing 0.4Hz data.

# %%
import glob
import os

# scratch = '/scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1'
scratch = '/scratch/project_2004833/common_data/mojito/brickmarket/mojito_v1_0_0/data/EMRI/L1_0p4Hz'
# Use * as a wildcard for the parts that change
pattern = os.path.join(scratch, f'EMRI_731d_2.5s_L1_source{source_index}_*.h5')
files = glob.glob(pattern)
output = f'{os.getcwd()}/output'
if files:
    # If multiple versions, sort on stimestamps
    L1_file_path = sorted(files)[-1] 
    print(f"Selected: {L1_file_path}")
else:
    print("No file found for that source index.")
# Out:
# Selected: /scratch/project_2004833/common_data/mojito/brickmarket/mojito_v1_0_0/data/EMRI/L1_0p4Hz/EMRI_731d_2.5s_L1_source1_0_20251203T225452097594Z.h5

# %%
from mojito import MojitoL1File    
with MojitoL1File(L1_file_path) as f:

    # Timing parameters
    # l01_t0 = f['tdis/sampling'].attrs['t0']
    # l01_dt = f['tdis/sampling'].attrs['dt']
    # l01_size = f['tdis/sampling'].attrs['size']
    
    tdi_time_sampling = f.tdis.time_sampling
    tdi_dt = tdi_time_sampling.dt
    
    # TDI observables
    CENTRAL_FREQ = f.laser_frequency
    print(CENTRAL_FREQ)
    
    x2 = f.tdis.x2[:] / CENTRAL_FREQ  # TDI X2 observable in Hz
    y2 = f.tdis.y2[:] / CENTRAL_FREQ # TDI Y2 observable in Hz
    z2 = f.tdis.z2[:] / CENTRAL_FREQ # TDI Z2 observable in Hz
# Out:
# 281600000000000.0

# %%
dt = delta_t = tdi_dt

# %%
x2.shape
# Out:
# (25246480,)

# %%
len_waveform = int(x2.shape[0] + 2* (550/dt + 1000))
# del x2, y2, z2
len_waveform
# Out:
# 25248920

# %% [markdown]
# The difference in the length of the simulation and the length of the generated waveform:

# %% [markdown]
# This is the extra part of the waveform that we need to generate: given as a number of samples

# %%
Time = len_waveform / ASTRONOMICAL_YEAR *dt

# %%
tdi_time_sampling.t0
# Out:
# 97729939.827664

# %% [markdown]
# ### Inspect Mojito timing
# These functions come from the timing module in the simulation pipeline.

# %%
def get_mojito_timing(
        oemorbits,
        dt,
        t_dltt_orbits,
        dt_orbits,
        t_strain_offset,
        n_trim_lolipops,
        n_orbit_buffer,
        window_jaxgbresponse,
    ) -> dict:
        """This function derives all timings relevant for Mojito, and generates the
        orbits file and groundtracking file.
        """
        # round up to integer multiple of `dt`
        duration_mojito_light = np.ceil(2.0 * ASTRONOMICAL_YEAR / dt) * dt

        # time reference from orbits file
        orbits = OEMOrbits.from_included(oemorbits)
        t0_orbits = float(orbits.t_start) + t_dltt_orbits

        # sizes: L1 has "+1" to cover full 2-year extent
        size_l1 = int(np.round(duration_mojito_light / dt)) + 1
        size_l0 = size_l1 + 2 * n_trim_lolipops
        size_strain = size_l0 + int(2 * np.ceil(t_strain_offset / dt))
        size_orbits = (
            int(
                np.ceil(((1 + 2 * window_jaxgbresponse) * size_l0 - 1) * dt / dt_orbits)
            )
            + 1
            + 2 * n_orbit_buffer
        )

        # time definitions
        t0_l0 = (
            t0_orbits + n_orbit_buffer * dt_orbits + window_jaxgbresponse * size_l0 * dt
        )
        t_init = t0_l0 - t_strain_offset
        timing_dict = {
            "dt": dt,
            "t_dltt_orbits": t_dltt_orbits,
            "dt_orbits": dt_orbits,
            "t_strain_offset": t_strain_offset,
            "n_trim_lolipops": n_trim_lolipops,
            "n_orbit_buffer": n_orbit_buffer,
            "window_jaxgbresponse": window_jaxgbresponse,
            "t0_orbits": t0_orbits,
            "size_l1": size_l1,
            "size_l0": size_l0,
            "size_strain": size_strain,
            "size_orbits": size_orbits,
            "t0_l0": t0_l0,
            "t_init": t_init,
        }
        return timing_dict

def create_orbits(oemorbits, timing, dense_orbits_path) -> None:
        """Create orbits file"""
        orbits = OEMOrbits.from_included(oemorbits)
        orbits.write(
            dense_orbits_path,    
            dt=timing["dt_orbits"],   
            size=timing["size_orbits"],
            t0=timing["t0_orbits"],
            mode="w",
        )

# %%
# create timing dictionary

t_dltt_orbits = 10.
dt_orbits = 5e5
t_strain_offset = 550
n_trim_lolipops = 1000
n_orbit_buffer = 10
window_jaxgbresponse = 0.5 

oemorbits =  "esa-trailing"

# %%
dt_orbits
# Out:
# 500000.0

# %%
timing = get_mojito_timing(
        oemorbits,
        dt,
        t_dltt_orbits,
        dt_orbits,
        t_strain_offset,
        n_trim_lolipops,
        n_orbit_buffer,
        window_jaxgbresponse)
# Out:
# Downloading file 'v2.0/crema_2p0/tcb_time_scale/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss_may_launch_lisa1.oem' from 'https://github.com/esa/lisa-orbit-files/raw/v2.0/crema_2p0/tcb_time_scale/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss_may_launch_lisa1.oem' to '/scratch/project_2004833/common_data/simdata/EMRI_ANALYSIS/tmp/.cache/lisaorbits'.
# 100%|█████████████████████████████████████| 85.1k/85.1k [00:00<00:00, 65.8MB/s]
# Downloading file 'v2.0/crema_2p0/tcb_time_scale/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss_may_launch_lisa2.oem' from 'https://github.com/esa/lisa-orbit-files/raw/v2.0/crema_2p0/tcb_time_scale/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss_may_launch_lisa2.oem' to '/scratch/project_2004833/common_data/simdata/EMRI_ANALYSIS/tmp/.cache/lisaorbits'.
# 100%|█████████████████████████████████████| 85.2k/85.2k [00:00<00:00, 67.2MB/s]
# Downloading file 'v2.0/crema_2p0/tcb_time_scale/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss_may_launch_lisa3.oem' from 'https://github.com/esa/lisa-orbit-files/raw/v2.0/crema_2p0/tcb_time_scale/mida-20deg/trajectory_out_mida-20deg_cw_sg-2nmss_may_launch_lisa3.oem' to '/scratch/project_2004833/common_data/simdata/EMRI_ANALYSIS/tmp/.cache/lisaorbits'.
# 100%|█████████████████████████████████████| 85.3k/85.3k [00:00<00:00, 63.0MB/s]
# OEM preferred interpolation method ignored, using spline interpolation (see InterpolatedOrbits for details)

# %%
timing
# Out:
# {'dt': 2.5,
#  't_dltt_orbits': 10.0,
#  'dt_orbits': 500000.0,
#  't_strain_offset': 550,
#  'n_trim_lolipops': 1000,
#  'n_orbit_buffer': 10,
#  'window_jaxgbresponse': 0.5,
#  't0_orbits': 61171239.327664,
#  'size_l1': 25246521,
#  'size_l0': 25248521,
#  'size_strain': 25248961,
#  'size_orbits': 274,
#  't0_l0': 97731890.577664,
#  't_init': 97731340.577664}

# %%
# timing
t0_l1 = tdi_time_sampling.t0
t0_l0 = t0_l1 - 1000*dt
t_init = t0_l0 - 550

# %%
print(f'''
t0_l1 = {t0_l1}
t0_l0 = {t0_l0}
t_init = {t_init}
''')
# Out:
# t0_l1 = 97729939.827664
# t0_l0 = 97727439.827664
# t_init = 97726889.827664

# %% [markdown]
# ## Build waveform object
# Set up the waveform object with right keywords

# %%
from fastlisaresponse.utils.parallelbase import ParallelModuleBase
# Set up correct arguments
sum_kwargs = {
    "pad_output": True,
}

inspiral_kwargs = {
    "DENSE_STEPPING": 0,  # sparsely sampled trajectory
    "max_init_len": int(1e8),  
}

amplitude_kwargs = {
    # "max_init_len": int(1e8),  # all of the trajectories will be well under len = 1000
    # "use_gpu": True,
    # "file_dir":"/data/leuven/367/vsc36785/LISA/FastEMRIWaveforms/data"
}

waveform_kwargs = {
    'mode_selection_threshold': 0.0
}

# %%
class EMRIWave_base(ParallelModuleBase):
    def __init__(self, force_backend=None, 
                use_gpu=True, 
                 inspiral_kwargs=inspiral_kwargs,
                 sum_kwargs=sum_kwargs,
                 amplitude_kwargs=amplitude_kwargs,
                 mode_selection_threshold=1e-5,
                 t_init=33568152.5,
                 t0_orbits=33568152.5,
                 dt=5, 
                 n_samples=1000,
                 offset=550, # seconds
                 time=2.0
                ):
                 
        super().__init__(force_backend=force_backend)
        
        self.use_gpu = use_gpu
        self.mode_threshold = mode_selection_threshold
        
        # Initialize waveform generator

        self.waveform_gen = GenerateEMRIWaveform(
                "FastKerrEccentricEquatorialFlux",
                return_list=False,    # returns hp - i*hx as a complex cupy array
                inspiral_kwargs=inspiral_kwargs,
                sum_kwargs=sum_kwargs,
                amplitude_kwargs=amplitude_kwargs,
                frame="detector"
            )
        self.t_init = t_init
        self.t0_orbits = t0_orbits
    
    @classmethod
    def supported_backends(cls):
        return ["fastlisaresponse_" + _tmp for _tmp in cls.GPU_RECOMMENDED()]

    def __call__(self, *params, T=2, dt=5):
        '''
        Call FEW waveform model and return the strain as h_+ - ih_x
        '''
        # define correct time grid for waveform generation.
        waveform_kwargs['T'] = T
        waveform_kwargs['dt'] = dt
        waveform_kwargs['mode_selection_threshold'] = self.mode_threshold
        strain = self.waveform_gen(*params, **waveform_kwargs)

        return strain

# %%
# get t0_orbits as done in Mojito simulation
orbits = OEMOrbits.from_included(oemorbits)
t0_orbits = float(orbits.t_start) + t_dltt_orbits

n_samples = 1000 # necessary to do the TDI delays
Tobs = 2 # years
offset = 550  # seconds

T = Tobs + (2* offset + 2*n_samples*dt)/ASTRONOMICAL_YEAR

use_gpu=True
t_smooth=0
waveform_model='Kerr'
mode_selection_threshold = 0.0

f_s = 1/dt   
home_folder = os.getcwd()
# Out:
# OEM preferred interpolation method ignored, using spline interpolation (see InterpolatedOrbits for details)

# %%
emri_waveform = EMRIWave_base(use_gpu=use_gpu, 
                         mode_selection_threshold=mode_selection_threshold,
                         t0_orbits=t0_orbits,
                         t_init=t_init,
                         dt=dt, 
                         n_samples=n_samples,
                         offset=offset, # seconds
                        )
# Out:
# Downloading 'ZNAmps_l10_m10_n55_DS2Outer.h5'... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:01:29
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Get source parameters
# get the source parameters from the catalog

# %%
from mojito.download import get_source_params

# Get source parameters for mbhb brick, source ID 12
params = get_source_params("emri", source_id=source_index, username=my_username, token=my_password)
# Out:
# Downloading file 'brickmarket/mojito_light_v1_0_0/catalogues/emri_cat_mojito_lite_processed_MT.hdf5' from 'https://nextcloud-dcc-fi-csc-okd-globalstorage1.2.rahtiapp.fi/remote.php/dav/files/bert-depoorter/brickmarket/mojito_light_v1_0_0/catalogues/emri_cat_mojito_lite_processed_MT.hdf5' to '/scratch/project_2004833/common_data/simdata/EMRI_ANALYSIS/tmp/.mojito_cache'.
# 100%|██████████████████████████████████████| 97.8k/97.8k [00:00<00:00, 187MB/s]
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.

# %%
params
# Out:
# {'AzimuthalAnglePrimarySpin': np.float64(5.713587723129935),
#  'AzimuthalPhase': np.float64(3.9359189585113032),
#  'ChirpMassSSBFrame': np.float64(1955.3186709723275),
#  'Declination': np.float64(-0.19442539592469896),
#  'Eccentricity': np.float64(0.14027289928151593),
#  'EstimatedSNR': np.float64(62.12555547852872),
#  'ID': np.int64(2),
#  'InclinationAngle': np.float64(0.0),
#  'LuminosityDistance': np.float64(1868.5054472836762),
#  'MassRatio': np.float64(5.500000000000001e-06),
#  'PolarAnglePrimarySpin': np.float64(2.830154648324706),
#  'PolarPhase': np.float64(0.36771585439807936),
#  'PrimaryMassSSBFrame': np.float64(2798983.9705247474),
#  'PrimaryMassSourceFrame': np.float64(2069091.0251730136),
#  'PrimarySpinParameter': np.float64(0.9725),
#  'RadialPhase': np.float64(4.873804097795071),
#  'Redshift': np.float64(0.3527601910557325),
#  'RightAscension': np.float64(5.2390554162169165),
#  'SecondaryMassSSBFrame': np.float64(15.394411837886114),
#  'SecondaryMassSourceFrame': np.float64(11.380000638451577),
#  'SemiLatusRectum': np.float64(4.862069),
#  'TimeCoalescencePetersSSBFrame': np.float64(27553411.487779915),
#  'TimeCoalescencePetersSourceFrame': np.float64(20368289.716063015),
#  'TimeCoalescenceSSBFrame': np.float64(44780589.604683),
#  'TimeReferenceSSBFrame': np.float64(97729089.327664),
#  'TotalMassSSBFrame': np.float64(2798999.3649365855)}

# %%
def icrs_to_ecliptic(ra, dec):
    """Convert ICRS coordinates (ra, dec) to ecliptic coordinates (lambda, beta)."""
    from astropy.coordinates import SkyCoord
    import astropy.units as u

    icrs_coord = SkyCoord(ra=ra * u.rad, dec=dec * u.rad, frame='icrs')
    ecliptic_coord = icrs_coord.barycentrictrueecliptic

    lambda_ecl = ecliptic_coord.lon.rad
    beta_ecl = ecliptic_coord.lat.rad

    return lambda_ecl, beta_ecl

# %%
ra = params['RightAscension']
dec = params['Declination']

lam_ecl, beta_ecl = icrs_to_ecliptic(ra, dec)
qS_ecl = np.pi / 2 - beta_ecl
phiS_ecl = lam_ecl

# %%
# extract source parameters
params_mojito = [
    params['PrimaryMassSSBFrame'],
    params['SecondaryMassSSBFrame'],
    params['PrimarySpinParameter'], #* np.sign(np.cos(params['InclinationAngle'])),
    params['SemiLatusRectum'],
    params['Eccentricity'],
    np.cos(params['InclinationAngle']),
    params['LuminosityDistance']*1e-3,
    qS_ecl,  # np.pi/2 - beta
    phiS_ecl,  # lambda
    params['PolarAnglePrimarySpin'],
    params['AzimuthalAnglePrimarySpin'],
    params['AzimuthalPhase'],
    params['PolarPhase'],
    params['RadialPhase'],
]

# %% [markdown]
# ### test waveform module

# %%
emri_test = emri_waveform(*params_mojito, T=Tobs, dt=dt)

# %%
time = np.arange(len(emri_test)) * dt

fig, ax = plt.subplots(1,1, figsize=(6,4))
ax.plot(time, emri_test.real.get())
ax.axvline(params['TimeCoalescenceSSBFrame'], color='black')

ax.set_xlim([0.99995* params['TimeCoalescenceSSBFrame'], 1.00001*params['TimeCoalescenceSSBFrame']])
# Out:
# (44778350.57520276, 44781037.41057905)

# %%
orbit_file= f'{home_folder}/esa-trailing-orbits-mojito_validation_test_2.h5'
force_backend = 'cuda12x'
esa = Orbits(filename=orbit_file, 
            use_gpu=use_gpu, 
            force_backend=force_backend, 
            linear_interp_setup=False,
            t0=t0_orbits)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:104, in Backend._check_module_installed(backend_name, module_name)
#     103 try:
# --> 104     importlib.import_module(module_name)
#     105 except ModuleNotFoundError as e:
#
# File /home/lisauser/miniforge3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1318, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'lisatools_backend_cuda12x'
#
# The above exception was the direct cause of the following exception:
#
# BackendNotInstalled                       Traceback (most recent call last)
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:358, in _CudaBackend.check_cuda_backend(cls, name, backend_module_name, cuda_min, cuda_max, module_loader, dynlib_loader)
#     357 try:
# --> 358     cls._check_module_installed(name, backend_module_name)
#     359 except BackendNotInstalled as e:
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:106, in Backend._check_module_installed(backend_name, module_name)
#     105 except ModuleNotFoundError as e:
# --> 106     raise BackendNotInstalled(
#     107         "The '{}' backend is not installed.".format(backend_name)
#     108     ) from e
#
# BackendNotInstalled: The 'cuda12x' backend is not installed.
#
# The above exception was the direct cause of the following exception:
#
# MissingDependencies                       Traceback (most recent call last)
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:673, in BackendsManager._try_loading_backend(self, backend_name)
#     671 try:
#     672     new_status = BackendStatusLoaded(
# --> 673         instance=self._known_backends[backend_name]()
#     674     )
#     675 except BackendUnavailableException as e:
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/lisatools/cutils/__init__.py:111, in LISAToolsCuda12xBackend.__init__(self, *args, **kwargs)
#     110 def __init__(self, *args, **kwargs):
# --> 111     Cuda12xBackend.__init__(self, *args, **kwargs)
#     112     LISAToolsBackend.__init__(self, self.cuda12x_module_loader())
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:555, in Cuda12xBackend.__init__(self)
#     554 name = "cuda12x"
# --> 555 methods = self.check_cuda_backend(
#     556     name=name,
#     557     backend_module_name=self.backend_name,
#     558     cuda_min=(12, 0),
#     559     cuda_max=(13, 0),
#     560     module_loader=self.__class__.cuda12x_module_loader,
#     561     dynlib_loader=self.__class__.cuda12x_dynlib_loader,
#     562 )
#     563 Feature = Backend.Feature
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:360, in _CudaBackend.check_cuda_backend(cls, name, backend_module_name, cuda_min, cuda_max, module_loader, dynlib_loader)
#     359 except BackendNotInstalled as e:
# --> 360     raise MissingDependencies(
#     361         "GPUBACKENDTOOLS CUDA plugin is missing.",
#     362         pip_deps=["gpubackendtools-cuda{}x".format(cuda_min[0])],
#     363         conda_deps=[],
#     364     ) from e
#     366 # 2. Check CuPy works with expected cuda major version
#
# MissingDependencies: GPUBACKENDTOOLS CUDA plugin is missing.
#     If you are using gpubackendtools in an environment managed using pip, run:
#         $ pip install gpubackendtools-cuda12x
#
#
#
# The above exception was the direct cause of the following exception:
#
# BackendAccessException                    Traceback (most recent call last)
# Cell In[46], line 3
#       1 orbit_file= f'{home_folder}/esa-trailing-orbits-mojito_validation_test_2.h5'
#       2 force_backend = 'cuda12x'
# ----> 3 esa = Orbits(filename=orbit_file,
#       4             use_gpu=use_gpu,
#       5             force_backend=force_backend,
#       6             linear_interp_setup=False,
#       7             t0=t0_orbits)
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/lisatools/detector.py:61, in Orbits.__init__(self, filename, armlength, force_backend, t0, **kwargs)
#      59 self._setup()
#      60 self.configured = False
# ---> 61 LISAToolsParallelModule.__init__(self, force_backend=force_backend)
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/lisatools/utils/parallelbase.py:11, in LISAToolsParallelModule.__init__(self, force_backend)
#       9 def __init__(self, force_backend=None):
#      10     force_backend_in = ('lisatools', force_backend) if isinstance(force_backend, str) else force_backend
# ---> 11     super().__init__(force_backend_in)
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/parallelbase.py:35, in ParallelModuleBase.__init__(self, force_backend)
#      31     assert isinstance(force_backend[0], str) and isinstance(
#      32         force_backend[1], str
#      33     )
#      34     force_backend = force_backend[0] + "_" + force_backend[1]
# ---> 35     self._backend_name = get_backend(force_backend).name
#      37 else:
#      38     raise ValueError("FIX THIS")
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/globals.py:404, in get_backend(backend_name)
#     401     _base = backend_name.split("_")[0]
#     402     return get_backend(_base + "_cuda")
# --> 404 return Globals().backends_manager.get_backend(backend_name=backend_name)
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:691, in BackendsManager.get_backend(self, backend_name)
#     685     raise BackendAccessException(
#     686         "Backend '{}' cannot be accessed, it has been disabled.".format(
#     687             backend_name
#     688         )
#     689     )
#     690 if isinstance(status, BackendStatusUnavailable):
# --> 691     raise BackendAccessException(
#     692         "Backend '{}' is unavailable. See previous error messages.".format(
#     693             backend_name
#     694         )
#     695     ) from status.reason
#     697 assert isinstance(status, BackendStatusLoaded)
#     698 return status.instance
#
# BackendAccessException: Backend 'lisatools_cuda12x' is unavailable. See previous error messages.

# %%
len(params_mojito)
# Out:
# 14

# %%
force_backend = "cuda12x" if use_gpu else None

index_beta = 7
index_lambda = 8

tdi_kwargs = {
    'tdi': '2nd generation',
    'tdi_chan': 'XYZ',
    'order': 39,
}

# %%
from fastlisaresponse.tdiconfig import TDIConfig
tdi_kwargs_esa = dict(
            orbits=esa,
            order=40,
            tdi=TDIConfig('2nd generation'),
            tdi_chan="XYZ",
        )

# %%
emri_TDI_list = ResponseWrapper(
    emri_waveform,
    T,
    dt,
    index_lambda,
    index_beta,
    t0=t_init,
    t_buffer = 10000.0,
    flip_hx=True,  # set to True if waveform is h+ - ihx
    force_backend=force_backend,
    remove_sky_coords=False,  # True if the waveform generator does not take sky coordinates
    is_ecliptic_latitude=False,  # False if using polar angle (theta)
    remove_garbage=False,  # removes the beginning of the signal that has bad information
    # orbits=esa,
    **tdi_kwargs_esa,
)
# Out:
# /home/lisauser/miniforge3/lib/python3.12/site-packages/fastlisaresponse/response.py:645: SyntaxWarning: invalid escape sequence '\p'
#   """Wrapper to produce LISA TDI from TD waveforms
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:104, in Backend._check_module_installed(backend_name, module_name)
#     103 try:
# --> 104     importlib.import_module(module_name)
#     105 except ModuleNotFoundError as e:
#
# File /home/lisauser/miniforge3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1318, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'fastlisaresponse_backend_cuda12x'
#
# The above exception was the direct cause of the following exception:
#
# BackendNotInstalled                       Traceback (most recent call last)
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:358, in _CudaBackend.check_cuda_backend(cls, name, backend_module_name, cuda_min, cuda_max, module_loader, dynlib_loader)
#     357 try:
# --> 358     cls._check_module_installed(name, backend_module_name)
#     359 except BackendNotInstalled as e:
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:106, in Backend._check_module_installed(backend_name, module_name)
#     105 except ModuleNotFoundError as e:
# --> 106     raise BackendNotInstalled(
#     107         "The '{}' backend is not installed.".format(backend_name)
#     108     ) from e
#
# BackendNotInstalled: The 'cuda12x' backend is not installed.
#
# The above exception was the direct cause of the following exception:
#
# MissingDependencies                       Traceback (most recent call last)
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:673, in BackendsManager._try_loading_backend(self, backend_name)
#     671 try:
#     672     new_status = BackendStatusLoaded(
# --> 673         instance=self._known_backends[backend_name]()
#     674     )
#     675 except BackendUnavailableException as e:
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/fastlisaresponse/cutils/__init__.py:166, in FastLISAResponseCuda12xBackend.__init__(self, *args, **kwargs)
#     165 def __init__(self, *args, **kwargs):
# --> 166     Cuda12xBackend.__init__(self, *args, **kwargs)
#     167     FastLISAResponseBackend.__init__(self, self.cuda12x_module_loader())
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:555, in Cuda12xBackend.__init__(self)
#     554 name = "cuda12x"
# --> 555 methods = self.check_cuda_backend(
#     556     name=name,
#     557     backend_module_name=self.backend_name,
#     558     cuda_min=(12, 0),
#     559     cuda_max=(13, 0),
#     560     module_loader=self.__class__.cuda12x_module_loader,
#     561     dynlib_loader=self.__class__.cuda12x_dynlib_loader,
#     562 )
#     563 Feature = Backend.Feature
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:360, in _CudaBackend.check_cuda_backend(cls, name, backend_module_name, cuda_min, cuda_max, module_loader, dynlib_loader)
#     359 except BackendNotInstalled as e:
# --> 360     raise MissingDependencies(
#     361         "GPUBACKENDTOOLS CUDA plugin is missing.",
#     362         pip_deps=["gpubackendtools-cuda{}x".format(cuda_min[0])],
#     363         conda_deps=[],
#     364     ) from e
#     366 # 2. Check CuPy works with expected cuda major version
#
# MissingDependencies: GPUBACKENDTOOLS CUDA plugin is missing.
#     If you are using gpubackendtools in an environment managed using pip, run:
#         $ pip install gpubackendtools-cuda12x
#
#
#
# The above exception was the direct cause of the following exception:
#
# BackendAccessException                    Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 emri_TDI_list = ResponseWrapper(
#       2     emri_waveform,
#       3     T,
#       4     dt,
#       5     index_lambda,
#       6     index_beta,
#       7     t0=t_init,
#       8     t_buffer = 10000.0,
#       9     flip_hx=True,  # set to True if waveform is h+ - ihx
#      10     force_backend=force_backend,
#      11     remove_sky_coords=False,  # True if the waveform generator does not take sky coordinates
#      12     is_ecliptic_latitude=False,  # False if using polar angle (theta)
#      13     remove_garbage=False,  # removes the beginning of the signal that has bad information
#      14     # orbits=esa,
#      15     **tdi_kwargs_esa,
#      16 )
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/fastlisaresponse/response.py:725, in ResponseWrapper.__init__(self, waveform_gen, Tobs, dt, index_lambda, index_beta, t0, t_buffer, flip_hx, remove_sky_coords, is_ecliptic_latitude, force_backend, remove_garbage, n_overide, orbits, **kwargs)
#     723 self.t_buffer = t_buffer
#     724 self.sampling_frequency = 1.0 / dt
# --> 725 super().__init__(force_backend=force_backend)
#     727 if orbits is None:
#     728     orbits = EqualArmlengthOrbits()
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/fastlisaresponse/utils/parallelbase.py:11, in FastLISAResponseParallelModule.__init__(self, force_backend)
#       9 def __init__(self, force_backend=None):
#      10     force_backend_in = ('fastlisaresponse', force_backend) if isinstance(force_backend, str) else force_backend
# ---> 11     super().__init__(force_backend_in)
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/parallelbase.py:35, in ParallelModuleBase.__init__(self, force_backend)
#      31     assert isinstance(force_backend[0], str) and isinstance(
#      32         force_backend[1], str
#      33     )
#      34     force_backend = force_backend[0] + "_" + force_backend[1]
# ---> 35     self._backend_name = get_backend(force_backend).name
#      37 else:
#      38     raise ValueError("FIX THIS")
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/globals.py:404, in get_backend(backend_name)
#     401     _base = backend_name.split("_")[0]
#     402     return get_backend(_base + "_cuda")
# --> 404 return Globals().backends_manager.get_backend(backend_name=backend_name)
#
# File /home/lisauser/miniforge3/lib/python3.12/site-packages/gpubackendtools/gpubackendtools.py:691, in BackendsManager.get_backend(self, backend_name)
#     685     raise BackendAccessException(
#     686         "Backend '{}' cannot be accessed, it has been disabled.".format(
#     687             backend_name
#     688         )
#     689     )
#     690 if isinstance(status, BackendStatusUnavailable):
# --> 691     raise BackendAccessException(
#     692         "Backend '{}' is unavailable. See previous error messages.".format(
#     693             backend_name
#     694         )
#     695     ) from status.reason
#     697 assert isinstance(status, BackendStatusLoaded)
#     698 return status.instance
#
# BackendAccessException: Backend 'fastlisaresponse_cuda12x' is unavailable. See previous error messages.

# %%
def emri_TDI(*params):
    return cp.asarray(emri_TDI_list(*params))

# %%
chans = emri_TDI(*params_mojito)

# %%
time = np.arange(len(chans[0])) * dt / YRSID_SI

# %%
fig, ax = plt.subplots(3, 1, sharex=True)

for i, lab in enumerate(["X", "Y", "Z"]):
    ax[i].plot(time[::10], chans[i].get()[::10])
    # ax[i].set_xlim([1.999, 2.001])
    ax[i].set_ylabel(lab)

# %%
chans.shape
# Out:
# (3, 25248959)

# %%
x2.shape
# Out:
# (25246480,)

# %%
25248959 - 25246480
# Out:
# 2479

# %%
850.5 / dt
# Out:
# 340.2

# %%
fig, ax = plt.subplots(3, 1, sharex=True)

for i, lab in enumerate(["X", "Y", "Z"]):
    ax[i].plot(time[:10000], chans[i].get()[:10000])
    ax[0].plot(time[:10000]+850.5/ASTRONOMICAL_YEAR, x2[:10000])
    ax[1].plot(time[:10000]+850.5/ASTRONOMICAL_YEAR, y2[:10000])
    ax[2].plot(time[:10000]+850.5/ASTRONOMICAL_YEAR, z2[:10000])
    ax[i].set_xlim([0.0004, 0.0007])
    ax[i].set_ylabel(lab)

# %% [markdown]
# ### Comparison plots

# %%
dt
# Out:
# 2.5

# %%
time_sim_L1 = np.arange(t_init + 850.5, x2.shape[0]*delta_t + t_init + 850.5, dt)[:-1]  
time_flr_L1 = np.arange(t_init, chans.shape[1]*delta_t + t_init, dt)[:-1]

# %%
len(chans[0])
# Out:
# 25248959

# %%
time_flr_L1.shape
# Out:
# (25248959,)

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))


ax.plot(time_sim_L1, x2, label='SIM X')   
ax.plot(time_flr_L1, chans[0].get(), label='FLR X channel')
ax.set_xlim([time_sim_L1[0], time_sim_L1[-1]])
ax.legend(loc='upper left')
ax.set_title('TDI X channel')
plt.show()
fig.clear()

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))


ax.plot(time_sim_L1, y2, label='SIM Y')   
ax.plot(time_flr_L1, chans[1].get(), label='FLR Y channel')
ax.set_xlim([time_sim_L1[0], time_sim_L1[-1]])
ax.legend(loc='upper left')
ax.set_title('TDI Y channel')
plt.show()
fig.clear()

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 4))

ax.plot(time_flr_L1, chans[2].get(), label='FLR Z channel')
ax.plot(time_sim_L1, z2, label='SIM Z')   
# ax.plot(time_flr_L1, chans[2].get(), label='FLR Z channel')
ax.set_xlim([time_sim_L1[0], time_sim_L1[-1]])
ax.legend(loc='upper left')
ax.set_title('TDI Z channel')
plt.show()
fig.clear()

# %%
T_plunge = params['TimeCoalescenceSSBFrame'] + t_init - 50.5

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4))
labels = ['X', 'Y', 'Z']
sim_data = {0: x2, 1: y2, 2: z2}

for i, lab in enumerate(labels):
    ax[i].plot(time_sim_L1, sim_data[i], label=f'SIM ')   
    ax[i].plot(time_flr_L1, chans[i].get(), label=f'FLR')
    ax[i].set_xlim([0.99999 * T_plunge, 1.00001 * T_plunge])
    ax[i].axvline(T_plunge, linestyle='--', color='black', label='Time of plunge')
    ax[i].legend(loc='upper left')
    
    ax[i].set_title(f'TDI {lab} channel')

# %%
channels = ['TDI X', 'TDI Y', 'TDI Z']
for i, chan in enumerate(channels):
    fig = plt.figure(figsize=(12, 8))
    gs = fig.add_gridspec(2, 2)

    # panel with full thing
    ax_top = fig.add_subplot(gs[0, :]) # Spans row 0, all columns
    ax_top.plot(time_flr_L1[::4], chans[0][::4].get(), label=f'FLR {chan} channel', alpha=0.7)
    ax_top.plot(time_sim_L1[::4], x2[::4], label=f'SIM {chan}', linestyle='--')
    ax_top.set_xlim([time_sim_L1[0], time_sim_L1[-1]])
    ax_top.set_title(f'Full TDI {chan} Channel Comparison')
    ax_top.legend(loc='upper right')
    ax_top.set_xlabel('Time in seconds')
    ax_top.set_ylabel('Amplitude')

    # bottom left
    ax_left = fig.add_subplot(gs[1, 0])
    ax_left.plot(time_flr_L1[:10000], chans[0][:10000].get(), label=f'FLR {chan} channel')
    ax_left.plot(time_sim_L1[:10000], x2[:10000], label=f'SIM {chan}')   
    # ax_left.set_xlim([(time_sim_L1[0])+1000*dt, (time_sim_L1[0]+ 0.00005)+8000*dt])
    ax_left.set_ylim([-5e-23, 5e-23])
    ax_left.legend(loc='upper left')
    ax_left.set_xlabel('Time in seconds')
    ax_left.set_title('Zoomed Comparison (Start)')

    # Bottom right
    ax_right = fig.add_subplot(gs[1, 1])
    ax_right.plot(time_flr_L1, chans[0].get(), label=f'FLR {chan} channel')
    ax_right.plot(time_sim_L1, x2, label=f'SIM {chan}')   
    ax_right.set_xlim([0.99999*T_plunge, 1.000001*T_plunge])
    # ax_right.set_xlim([(4.26612)*YRSID_SI/dt, (4.26615)*YRSID_SI/dt])
    ax_right.legend(loc='upper left')
    ax_right.set_xlabel('Time in seconds')
    ax_right.set_title('Zoomed Comparison (Plunge)')

    plt.tight_layout()
    plt.show()
    fig.savefig(f'{output}/source_{source_index}/{chan}_TD_comparison.png', dpi=300)

    fig.clear()

# %% [markdown]
# ### Mismatch and SNR computations

# %%
from lisatools.datacontainer import DataResidualArray
from lisatools.analysiscontainer import AnalysisContainer
from lisatools.sensitivity import SensitivityMatrix

from lisatools.domains import TDSettings, FDSettings, FDSignal, TDSignal

# %%
chans.shape
# Out:
# (3, 25248959)

# %%
tdi_channels_here = np.array([tdi_channel.get() for tdi_channel in chans])

# %%
# now spline interpolate the tdi channels to the same time array as the data
from scipy.interpolate import CubicSpline
window = tukey(len(time_sim_L1), alpha=0.01)

xyz_splined = np.array([
    CubicSpline(time_flr_L1, chan)(time_sim_L1) for chan in tdi_channels_here
])

# %%
NPLOT = int(1e9)

plt.plot(time_sim_L1[:NPLOT], x2[:NPLOT], label='L1 X')
plt.plot(time_sim_L1[:NPLOT], xyz_splined[0][:NPLOT], alpha=0.7, label='EMRI waveform X', c='k', ls='--')

# %%
data = cp.asarray([x2, y2, z2])
xyz_residual = data - cp.asarray(xyz_splined)
xyz_residual_windowed = xyz_residual * cp.asarray(window)

# %%
# window signal
xyz_residual_windowed = xyz_residual * cp.asarray(window)
xyz_data_windowed = data * cp.asarray(window)
xyz_splined_windowed = cp.asarray(xyz_splined) * cp.asarray(window)

# apply fft
xyz_residual_fft = cp.fft.rfft(xyz_residual_windowed, axis=1)
xyz_data_fft = cp.fft.rfft(xyz_data_windowed, axis=1)
xyz_splined_fft = cp.fft.rfft(xyz_splined_windowed, axis=1)


N_t = len(data[0])
freqs = cp.fft.rfftfreq(N_t, d=dt)

f_max = 1/(2*dt) # Nyquist frequency
f_min = 1e-5 # minimum frequency to consider
mask = (freqs >= f_min) & (freqs <= f_max)
freqs_inband = freqs[mask]

# filter frequencies
xyz_data_fft_inband = xyz_data_fft[:, mask]
xyz_splined_fft_inband = xyz_splined_fft[:, mask]
xyz_residual_fft_inband = xyz_residual_fft[:, mask]

# %%
xyz_residual_fft_inband.shape
# Out:
# (3, 12622609)

# %%
freqs_inband.shape
# Out:
# (12622609,)

# %%
# load noise estimates
CENTRAL_FREQ = 281600000000000.0
noise_file = f"{scratch}/../../NOISE/L1/NOISE_731d_2.5s_L1_source0_0_20251206T220508924302Z.h5"

with h5py.File(noise_file, "r") as f:
    xyz_noise_estimate = np.mean(f['noise_estimates/XYZ'][:], axis=0) / CENTRAL_FREQ**2
    fmin_noise_psd = f['noise_estimates/log_frequency_sampling'].attrs['fmin']
    fmax_noise_psd = f['noise_estimates/log_frequency_sampling'].attrs['fmax']
    size_noise_psd = f['noise_estimates/log_frequency_sampling'].attrs['size']

    noise_freqs = np.logspace(np.log10(fmin_noise_psd), np.log10(fmax_noise_psd), size_noise_psd)

# %%
xyz_noise_estimate.shape
# Out:
# (1000, 3, 3)

# %%
# make plots

channels = ['TDI x', 'TDI Y', 'TDI Z']
for i, chan in enumerate(channels):
    fig, axs = plt.subplots(1, 1, figsize=(10, 8))
    DecimFactor = 50
    axs.loglog(freqs_inband[::DecimFactor].get(), np.abs(xyz_data_fft_inband[i, ::DecimFactor].get())**2, 
               label='Data')
    axs.loglog(freqs_inband[::DecimFactor].get(), np.abs(xyz_splined_fft_inband[i, ::DecimFactor].get())**2, 
               label='WF + FLR', c='k', ls='--', alpha=0.8)
    axs.loglog(freqs_inband[::DecimFactor].get(), np.abs(xyz_residual_fft_inband[i, ::DecimFactor].get())**2, 
               c='gray', alpha=0.8, zorder=0, label='Residual')
    
    axs.loglog(noise_freqs, np.abs(xyz_noise_estimate[:, i, i]), linestyle='dashed', color='red')

    axs.set_title(f"{chan} channel")
    axs.legend(loc='lower left')

    axs.set_xlabel("Frequency [Hz]")
    axs.set_ylabel("ASD [1/sqrt(Hz)]")


    # plt.ylim(1e-26, 1e-17)
    axs.grid(True, which='both')
    plt.show()
    fig.savefig(f'{output}/source_{source_index}/{chan}_FD_comparison.png')
    #plt.xlim(1e-5, 0.2)

    fig.clear()

# %% [markdown]
# We see some mismatch at the lower and upper frequency bounds. At the high frequencies this may be attributed to the downsampling applied on the full 4Hz simulated data. Need to check this by generating the data at 4Hz with FLR. Maybe too memory-intensive to perform well.

# %%
noise_file
# Out:
# '/scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/../../NOISE/L1/NOISE_731d_2.5s_L1_source0_0_20251206T220508924302Z.h5'

# %%
# define noise psd interpolant

freqs_inband_np = np.asarray(freqs_inband.get())

splined_noise_psd = np.array([
    CubicSpline(noise_freqs, xyz_noise_estimate[:, i, i])(freqs_inband_np) for i in range(3)
])

splined_noise_csd_real = np.array([
    CubicSpline(noise_freqs, xyz_noise_estimate[:, i, j].real)(freqs_inband_np) for i in range(3) for j in range(i, 3)
])

splined_noise_psd_imag = np.array([
    CubicSpline(noise_freqs, xyz_noise_estimate[:, i, j].imag)(freqs_inband_np) for i in range(3) for j in range(i, 3)   
])

# %%
# now re-assemble the covariance matrix
covariance_matrices = np.zeros((3, 3, len(freqs_inband)), dtype=complex)
for i in range(3):
    covariance_matrices[i, i, :] = splined_noise_psd[i]
    for j in range(i+1, 3):
        covariance_matrices[i, j, :] = splined_noise_csd_real[i*3 + j - (i+1)*i//2] + 1j * splined_noise_psd_imag[i*3 + j - (i+1)*i//2]
        covariance_matrices[j, i, :] = np.conj(covariance_matrices[i, j, :])

# %%
invC = np.linalg.inv(covariance_matrices.transpose(2, 0, 1))#.transpose(1, 2, 0)

# %%
invC.shape
# Out:
# (12622609, 3, 3)

# %% [markdown]
# #### Personal SNR function
# This function works but suffers from numerical instability when inverting the covariance matrix, due to negative and complex values in the CSD arrays. This should be addressed more robustly.

# %%
freqs_inband_np.shape
# Out:
# (12622609,)

# %%
covariance_matrices.shape
# Out:
# (3, 3, 12622609)

# %%
fig, axs = plt.subplots(3,3, figsize=(10, 10))

for i in range(3):
    for j in range(3):
        axs[i, j].loglog(freqs_inband_np[::5], np.abs(covariance_matrices[i, j, :][::5]), label='abs')
        axs[i, j].loglog(freqs_inband_np[::5], np.real(covariance_matrices[i, j, :][::5]), label='real')
        axs[i, j].loglog(freqs_inband_np[::5], np.imag(covariance_matrices[i, j, :][::5]), label='imag')
        axs[i, j].grid(True, which='both')
fig.clear()

# %%
fig, axs = plt.subplots(3,3, figsize=(10, 10))

for i in range(3):
    for j in range(3):
        axs[i, j].loglog(freqs_inband_np[::5], np.abs(covariance_matrices[i, j, :][::5]))
        axs[i, j].loglog(freqs_inband_np[::5], np.imag(covariance_matrices[i, j, :][::5]))
        axs[i, j].loglog(freqs_inband_np[::5], np.real(covariance_matrices[i, j, :][::5]))
        axs[i, j].grid(True, which='both')
        
fig.clear()

# %%
def inner_prod_tdi(a_fft, b_fft, cov_inv_matrices):
    """
    Compute noise-weighted inner product for TDI multi-channel data with correlated noise.
    Time-Delay Interferometry (TDI) produces three channels (X, Y, Z) with correlated
    noise. This function computes the proper inner product accounting for these
    correlations using the inverse covariance matrix.
    Mathematical form:
        ⟨a|b⟩ = 2 Re[Σₖ aₖ† Σₖ⁻¹ bₖ]
    where at each frequency bin k:
        - aₖ, bₖ are 3D complex vectors [X_k, Y_k, Z_k]
        - Σₖ⁻¹ is the 3×3 inverse covariance matrix
    Parameters
    ----------
    a_fft : array-like, complex, shape (3, n_freq)
        First frequency-domain TDI waveform [X, Y, Z] × frequencies
    b_fft : array-like, complex, shape (3, n_freq)
        Second frequency-domain TDI waveform [X, Y, Z] × frequencies
    cov_inv_matrices : array-like, float, shape (n_freq, 3, 3)
        Inverse covariance matrices for each frequency bin
        Pre-multiplied by prefactor (typically 2*dt/N)
    Returns
    -------
    float
        Noise-weighted inner product accounting for correlations between channels
    Notes
    -----
    - Uses Einstein summation (einsum) for efficient vectorized computation
    - At each frequency: result[k] = conj(a[k]).T @ Σ⁻¹[k] @ b[k]
    - The covariance matrix is NOT diagonal due to TDI channel correlations
    - Essential for computing SNRs and Fisher matrices in TDI analysis
    Implementation Details
    ----------------------
    The computation uses Einstein notation 'fj,fjk,fk->f' which means:
        f : frequency index
        j : first TDI channel index (for a)
        k : second TDI channel index (for b)
    This computes: Σⱼₖ conj(a[f,j]) * Σ⁻¹[f,j,k] * b[f,k] for each frequency
    See Also
    --------
    inner_prod : Simpler inner product for single-channel data
    """
    # Reshape from (3, n_freq) to (n_freq, 3) to align with covariance matrix indexing
    # This makes frequency the leading dimension for efficient vectorized operations
    a_fft_T = a_fft.T  # Shape: (n_freq, 3) - [X, Y, Z] for each frequency
    b_fft_T = b_fft.T  # Shape: (n_freq, 3) - [X, Y, Z] for each frequency
    # Compute matrix product for each frequency: aₖ† Σₖ⁻¹ bₖ
    # Einstein summation notation 'fj,fjk,fk->f' performs:
    #   f = frequency index (output dimension)
    #   j = TDI channel for left vector (a)
    #   k = TDI channel for right vector (b)
    #
    # For each frequency f, computes:
    #   Σⱼ Σₖ conj(a[f,j]) * Σ⁻¹[f,j,k] * b[f,k]
    # which is equivalent to the matrix product: a†[f] @ Σ⁻¹[f] @ b[f]
    inner_per_freq = np.einsum('fj,fjk,fk->f',
                               np.conj(a_fft_T),
                               cov_inv_matrices,
                               b_fft_T)
    # Sum over all frequencies and extract real part
    # Factor of 2 accounts for positive and negative frequencies (one-sided spectrum)
    inner_product = 2 * np.real(np.sum(inner_per_freq))
    return inner_product

# %%
def SNR(signal, invC):
    return np.sqrt(inner_prod_tdi(signal, signal, invC))

# %%
def match(s1, s2, invC):
    ip12 = inner_prod_tdi(s1, s2, invC)
    ip11 = inner_prod_tdi(s1, s1, invC)
    ip22 = inner_prod_tdi(s2, s2, invC)
    return ip12 / np.sqrt(ip11 * ip22)

def mismatch(s1, s2, invC):
    return 1 - match(s1, s2, invC)

# %% [markdown]
# Here I need to check out the normalization for the FFT: divide over the `N_t= len(data)` in time domain or `N_f=len(freqs_inband)`, the frequency array over which we compute the inner product integral.

# %%
pre_fact = 2 * dt / N_t
invC *= pre_fact

SNR_data = SNR(xyz_data_fft_inband, invC)
SNR_wf = SNR(xyz_splined_fft_inband, invC)
SNR_residual = SNR(xyz_residual_fft_inband, invC)

# %%
msimatch_data = mismatch(xyz_data_fft_inband, xyz_splined_fft_inband, invC)

# %%
print(f'''
Source {source_index} summary
------------------------------
SNR data:      {SNR_data}
SNR template:  {SNR_wf}
SNR residual:  {SNR_residual}

mismatch data - template: {msimatch_data}
''')
# Out:
# Source 1 summary
# ------------------------------
# SNR data:      59.44748014856629
# SNR template:  59.446941210045566
# SNR residual:  0.2660188934876504
#
# mismatch data - template: 1.0012216298704857e-05

# %%
SNR_msimatch_data = np.zeros((8, 4))

# %% [markdown]
# ### Loop over sources

# %%
for source_index in range(8):
    # Get source parameters for mbhb brick, source ID 12
    params = get_source_params("emri", source_id=source_index, username='bert-depoorter', token='2c7#QBB9DTh8QgJPpw')
    ra = params['RightAscension']
    dec = params['Declination']

    lam_ecl, beta_ecl = icrs_to_ecliptic(ra, dec)
    qS_ecl = np.pi / 2 - beta_ecl
    phiS_ecl = lam_ecl

    # define EMRI params
    params_mojito = [
        params['PrimaryMassSSBFrame'],
        params['SecondaryMassSSBFrame'],
        params['PrimarySpinParameter'], #* np.sign(np.cos(params['InclinationAngle'])),
        params['SemiLatusRectum'],
        params['Eccentricity'],
        np.cos(params['InclinationAngle']),
        params['LuminosityDistance']*1e-3,
        qS_ecl,  # np.pi/2 - beta
        phiS_ecl,  # lambda
        params['PolarAnglePrimarySpin'],
        params['AzimuthalAnglePrimarySpin'],
        params['AzimuthalPhase'],
        params['PolarPhase'],
        params['RadialPhase'],
    ]
    
    # Get response channels
    chans = emri_TDI(*params_mojito)
    
    # Load correct data
    pattern = os.path.join(scratch, f'EMRI_731d_2.5s_L1_source{source_index}_*.h5')
    files = glob.glob(pattern)
    output = f'{os.getcwd()}/output'
    if files:
        # If multiple versions, sort on stimestamps
        L1_file_path = sorted(files)[-1] 
        print(f"Selected: {L1_file_path}")
    else:
        print("No file found for that source index.")
    
    with MojitoL1File(L1_file_path) as f:

        # Timing parameters
        # l01_t0 = f['tdis/sampling'].attrs['t0']
        # l01_dt = f['tdis/sampling'].attrs['dt']
        # l01_size = f['tdis/sampling'].attrs['size']

        tdi_time_sampling = f.tdis.time_sampling
        tdi_dt = tdi_time_sampling.dt

        # TDI observables
        CENTRAL_FREQ = f.laser_frequency
        print(CENTRAL_FREQ)

        x2 = f.tdis.x2[:] / CENTRAL_FREQ  # TDI X2 observable in Hz
        y2 = f.tdis.y2[:] / CENTRAL_FREQ # TDI Y2 observable in Hz
        z2 = f.tdis.z2[:] / CENTRAL_FREQ # TDI Z2 observable in Hz
    
    # transform data
    data = cp.asarray([x2, y2, z2])
    tdi_channels_here = np.array([tdi_channel.get() for tdi_channel in chans])
    xyz_splined = np.array([
        CubicSpline(time_flr_L1, chan)(time_sim_L1) for chan in tdi_channels_here
    ])
    
    # create residual array
    xyz_residual = data - cp.asarray(xyz_splined)
    xyz_residual_windowed = xyz_residual * cp.asarray(window)

    
    xyz_residual_windowed = xyz_residual * cp.asarray(window)
    xyz_data_windowed = data * cp.asarray(window)
    xyz_splined_windowed = cp.asarray(xyz_splined) * cp.asarray(window)

    # apply fft
    xyz_residual_fft = cp.fft.rfft(xyz_residual_windowed, axis=1)
    xyz_data_fft = cp.fft.rfft(xyz_data_windowed, axis=1)
    xyz_splined_fft = cp.fft.rfft(xyz_splined_windowed, axis=1)


    N_t = len(data[0])
    freqs = cp.fft.rfftfreq(N_t, d=dt)

    f_max = 1/(2*dt) # Nyquist frequency
    f_min = 1e-5 # minimum frequency to consider
    mask = (freqs >= f_min) & (freqs <= f_max)
    freqs_inband = freqs[mask]

    # filter frequencies
    xyz_data_fft_inband = xyz_data_fft[:, mask]
    xyz_splined_fft_inband = xyz_splined_fft[:, mask]
    xyz_residual_fft_inband = xyz_residual_fft[:, mask]

    # Make TD plots
    channels = ['TDI X', 'TDI Y', 'TDI Z']
    for i, chan in enumerate(channels):
        fig = plt.figure(figsize=(12, 8))
        gs = fig.add_gridspec(2, 2)

        # panel with full thing
        ax_top = fig.add_subplot(gs[0, :]) # Spans row 0, all columns
        ax_top.plot(time_flr_L1[::4], chans[0][::4].get(), label=f'FLR {chan} channel', alpha=0.7)
        ax_top.plot(time_sim_L1[::4], x2[::4], label=f'SIM {chan}', linestyle='--')
        ax_top.set_xlim([time_sim_L1[0], time_sim_L1[-1]])
        ax_top.set_title(f'Full TDI {chan} Channel Comparison')
        ax_top.legend(loc='upper right')
        ax_top.set_xlabel('Time in seconds')
        ax_top.set_ylabel('Amplitude')

        # bottom left
        ax_left = fig.add_subplot(gs[1, 0])
        ax_left.plot(time_flr_L1[:10000], chans[0][:10000].get(), label=f'FLR {chan} channel')
        ax_left.plot(time_sim_L1[:10000], x2[:10000], label=f'SIM {chan}')   
        # ax_left.set_xlim([(time_sim_L1[0])+1000*dt, (time_sim_L1[0]+ 0.00005)+8000*dt])
        ax_left.set_ylim([-5e-23, 5e-23])
        ax_left.legend(loc='upper left')
        ax_left.set_xlabel('Time in seconds')
        ax_left.set_title('Zoomed Comparison (Start)')

        # Bottom right
        ax_right = fig.add_subplot(gs[1, 1])
        ax_right.plot(time_flr_L1, chans[0].get(), label=f'FLR {chan} channel')
        ax_right.plot(time_sim_L1, x2, label=f'SIM {chan}')   
        ax_right.set_xlim([0.99999*T_plunge, 1.000001*T_plunge])
        # ax_right.set_xlim([(4.26612)*YRSID_SI/dt, (4.26615)*YRSID_SI/dt])
        ax_right.legend(loc='upper left')
        ax_right.set_xlabel('Time in seconds')
        ax_right.set_title('Zoomed Comparison (Plunge)')

        plt.tight_layout()
        plt.show()
        fig.savefig(f'{output}/source_{source_index}/{chan}_TD_comparison.png', dpi=300)

        fig.clear()
        
    # Make FD plots
    channels = ['TDI x', 'TDI Y', 'TDI Z']
    for i, chan in enumerate(channels):
        fig, axs = plt.subplots(1, 1, figsize=(10, 8))
        DecimFactor = 50
        axs.loglog(freqs_inband[::DecimFactor].get(), np.abs(xyz_data_fft_inband[i, ::DecimFactor].get())**2, 
                   label='Data')
        axs.loglog(freqs_inband[::DecimFactor].get(), np.abs(xyz_splined_fft_inband[i, ::DecimFactor].get())**2, 
                   label='WF + FLR', c='k', ls='--', alpha=0.8)
        axs.loglog(freqs_inband[::DecimFactor].get(), np.abs(xyz_residual_fft_inband[i, ::DecimFactor].get())**2, 
                   c='gray', alpha=0.8, zorder=0, label='Residual')

        axs.loglog(noise_freqs, np.abs(xyz_noise_estimate[:, i, i]), linestyle='dashed', color='red')

        axs.set_title(f"{chan} channel")
        axs.legend(loc='lower left')

        axs.set_xlabel("Frequency [Hz]")
        axs.set_ylabel("ASD [1/sqrt(Hz)]")


        # plt.ylim(1e-26, 1e-17)
        axs.grid(True, which='both')
        plt.show()
        fig.savefig(f'{output}/source_{source_index}/{chan}_FD_comparison.png')
        #plt.xlim(1e-5, 0.2)

        fig.clear()
    # Compute mismatch and SNR
    SNR_data = SNR(xyz_data_fft_inband, invC)
    SNR_wf = SNR(xyz_splined_fft_inband, invC)
    SNR_residual = SNR(xyz_residual_fft_inband, invC)
    
    msimatch_data = mismatch(xyz_data_fft_inband, xyz_splined_fft_inband, invC)
    
    # save data
    SNR_msimatch_data[source_index, 0] = SNR_data
    SNR_msimatch_data[source_index, 1] = SNR_wf
    SNR_msimatch_data[source_index, 2] = SNR_residual
    SNR_msimatch_data[source_index, 3] = msimatch_data
    
    
    print(f'''
    Source {source_index} summary
    ------------------------------
    SNR data:      {SNR_data}
    SNR template:  {SNR_wf}
    SNR residual:  {SNR_residual}

    mismatch data - template: {msimatch_data}
    ''')
# Out:
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source0_0_20251203T225446987631Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 0 summary
#     ------------------------------
#     SNR data:      60.02321255116381
#     SNR template:  60.01921011803177
#     SNR residual:  0.19233517459008148
#
#     mismatch data - template: 5.132037440347403e-06
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source1_0_20251203T225452097594Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 1 summary
#     ------------------------------
#     SNR data:      59.44748014856629
#     SNR template:  59.446941210045566
#     SNR residual:  0.2660188934876504
#
#     mismatch data - template: 1.0012216298704857e-05
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source2_0_20251203T225634883009Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 2 summary
#     ------------------------------
#     SNR data:      87.09384997782448
#     SNR template:  87.09839542563907
#     SNR residual:  0.2953097624128503
#
#     mismatch data - template: 5.746786531202197e-06
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source3_0_20251203T230015480422Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 3 summary
#     ------------------------------
#     SNR data:      75.2702398075587
#     SNR template:  75.25916262027116
#     SNR residual:  0.5177434280684791
#
#     mismatch data - template: 2.3649266114977863e-05
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source4_0_20251203T230133634168Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 4 summary
#     ------------------------------
#     SNR data:      50.21526224354919
#     SNR template:  50.214853892759756
#     SNR residual:  0.164991099855736
#
#     mismatch data - template: 5.397845388332989e-06
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source5_0_20251203T230243827530Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 5 summary
#     ------------------------------
#     SNR data:      36.354997742626196
#     SNR template:  36.355189327867194
#     SNR residual:  0.0694818915571051
#
#     mismatch data - template: 1.8263307685062458e-06
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source6_0_20251203T231104263787Z.h5
# 281600000000000.0
# WARNING! Publications using Mojito data are currently not allowed! Please keep in touch, as publication policies will soon be published.
#     Source 6 summary
#     ------------------------------
#     SNR data:      85.40681464316273
#     SNR template:  85.41235827118835
#     SNR residual:  0.19620422723631797
#
#     mismatch data - template: 2.636493146579433e-06
#
# Selected: /scratch/leuven/367/vsc36785/MojitoLight/SIM_data/brickmarket/mojito_light_v1_0_0/data/EMRI/L1/EMRI_731d_2.5s_L1_source7_0_20251203T231827138749Z.h5
# 281600000000000.0
#     Source 7 summary
#     ------------------------------
#     SNR data:      66.60142644860403
#     SNR template:  66.59331827939671
#     SNR residual:  0.7333748756277307
#
#     mismatch data - template: 6.0625423270233014e-05

# %%
for i in range(8):
    print(f'''
    Source {i} summary
    ------------------------------
    SNR data:      {SNR_msimatch_data[i, 0]}
    SNR template:  {SNR_msimatch_data[i, 1]}
    SNR residual:  {SNR_msimatch_data[i, 2]}

    mismatch data - template: {SNR_msimatch_data[i, 3]}
    ''')
# Out:
#     Source 0 summary
#     ------------------------------
#     SNR data:      60.02321255116381
#     SNR template:  60.01921011803177
#     SNR residual:  0.19233517459008148
#
#     mismatch data - template: 5.132037440347403e-06
#
#
#     Source 1 summary
#     ------------------------------
#     SNR data:      59.44748014856629
#     SNR template:  59.446941210045566
#     SNR residual:  0.2660188934876504
#
#     mismatch data - template: 1.0012216298704857e-05
#
#
#     Source 2 summary
#     ------------------------------
#     SNR data:      87.09384997782448
#     SNR template:  87.09839542563907
#     SNR residual:  0.2953097624128503
#
#     mismatch data - template: 5.746786531202197e-06
#
#
#     Source 3 summary
#     ------------------------------
#     SNR data:      75.2702398075587
#     SNR template:  75.25916262027116
#     SNR residual:  0.5177434280684791
#
#     mismatch data - template: 2.3649266114977863e-05
#
#
#     Source 4 summary
#     ------------------------------
#     SNR data:      50.21526224354919
#     SNR template:  50.214853892759756
#     SNR residual:  0.164991099855736
#
#     mismatch data - template: 5.397845388332989e-06
#
#
#     Source 5 summary
#     ------------------------------
#     SNR data:      36.354997742626196
#     SNR template:  36.355189327867194
#     SNR residual:  0.0694818915571051
#
#     mismatch data - template: 1.8263307685062458e-06
#
#
#     Source 6 summary
#     ------------------------------
#     SNR data:      85.40681464316273
#     SNR template:  85.41235827118835
#     SNR residual:  0.19620422723631797
#
#     mismatch data - template: 2.636493146579433e-06
#
#
#     Source 7 summary
#     ------------------------------
#     SNR data:      66.60142644860403
#     SNR template:  66.59331827939671
#     SNR residual:  0.7333748756277307
#
#     mismatch data - template: 6.0625423270233014e-05

# %%
# function to stabilize the inversion of the covariance matrix
def stabilize_covariance_for_inversion(
    cov,
    psd_floor=1e-45,
    smooth_window_logfreq=15,
    return_inverse=True,
):
    """
    Stabilize covariance by smoothing magnitude in log-frequency space.

    Fast and robust: smooths away dips/spikes without costly eigendecomposition.

    Parameters
    ----------
    cov : np.ndarray, shape (n_ch, n_ch, n_freq)
        Complex covariance matrices.
    psd_floor : float
        Floor for smoothed magnitudes.
    smooth_window_logfreq : int
        Size of smoothing window in log-frequency (samples). Use ~10-20.
    return_inverse : bool
        If True, also return stable inverse.

    Returns
    -------
    cov_stable : np.ndarray, shape (n_ch, n_ch, n_freq)
        Stabilized Hermitian positive-definite covariance.
    inv_cov_stable : np.ndarray, optional
        Stable matrix inverse (via np.linalg.inv per frequency).
    """
    from scipy.ndimage import uniform_filter1d
    
    cov = np.asarray(cov, dtype=np.complex128)
    n_ch, _, n_f = cov.shape

    # 1) Extract magnitude and phase per matrix element
    mag = np.abs(cov)  # Shape: (n_ch, n_ch, n_freq)
    phase = np.angle(cov)  # Shape: (n_ch, n_ch, n_freq)

    # 2) Smooth magnitude in log-frequency space for each element
    mag_smooth = np.zeros_like(mag)
    for i in range(n_ch):
        for j in range(n_ch):
            # Log-smooth: apply uniform filter on log of magnitude
            log_mag = np.log(np.maximum(mag[i, j, :], psd_floor))
            log_mag_smooth = uniform_filter1d(log_mag, size=smooth_window_logfreq, mode='nearest')
            mag_smooth[i, j, :] = np.exp(log_mag_smooth)

    # 3) Reconstruct complex values with original phase
    cov_smooth = mag_smooth * np.exp(1j * phase)

    # 4) Enforce Hermitian structure
    cov_stable = 0.5 * (cov_smooth + cov_smooth.conj().transpose(1, 0, 2))

    # 5) Ensure diagonal is real and positive
    for k in range(n_f):
        d = np.real(np.diag(cov_stable[:, :, k]))
        d = np.maximum(d, psd_floor)
        np.fill_diagonal(cov_stable[:, :, k], d)

    if return_inverse:
        inv_cov_stable = np.empty_like(cov_stable)
        for k in range(n_f):
            inv_cov_stable[:, :, k] = np.linalg.inv(cov_stable[:, :, k])
        return cov_stable, inv_cov_stable

    return cov_stable

# %%
# Apply stabilization

covariance_matrices_stable, invC_stable = stabilize_covariance_for_inversion(
    covariance_matrices,
    psd_floor=1e-45,
    smooth_window_logfreq=15,  # Tune this: larger = smoother
)

invC = 

# Apply prefactor
pre_fact = 2 * dt / N_t
invC_for_ip = pre_fact * invC_stable
